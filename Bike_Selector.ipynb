# %% [markdown]
# <a href="https://colab.research.google.com/github/collinswm/Projects/blob/master/Bike_Selector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Identify Your Racebike**
# ---
#
# The objective of this task is to train a Convolutional Neural Network to recognise the brand of racebike based on preloaded images covering 13 classes each representing an major manufacturer.
#
# Becasue each of these bikes follows a very simimlar design aesthetic - mainly driven by fluid and aerodynamics considerations and also UCI rules on size and dimensions of frames and componetns there is very little to distinguish each bike.
#
# Early in the model you can see there is a very high error rate. However the process followed was to progressively retrain the model with higher epochs and a more refined learning rate to see if we can reach a stable / good enough model.
#
# As can be seen at the end, random images thrown at the resnet34 model are accurartely identified.

# %% [markdown]
# ### **Preprocessing**
#
# ---
#
#
#
# ---

# %% [markdown]
# ### Mount the Google Drive
#
# ---

# %%
# ### Mount the Gooogle Drive with source data

# from google.colab import drive
# drive.mount('/content/gdrive', force_remount=True)
# root_dir = "/content/gdrive/My Drive/"
# base_dir = root_dir + 'fastai-v3/'

# %% [markdown]
# ### Load the Libraries
#
#
# ---

# %%
### Load libraries

import os.path
from fastai.vision import *
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ### Download the sample images from Google Images
#
# ---
#
# Using Google Image Search, I have downloaded a sample of images which conform to the major wood types. This model will focus on Guitar Top Woods:
#
# The following images have been downloaded using Google Images (ctrl+option+J if using Google Chrome) followed by the next statement:
#
# **urls=Array.from(document.querySelectorAll('.rg_i')).map(el=> el.hasAttribute('data-src')?el.getAttribute('data-src'):el.getAttribute('data-iurl'));
# window.open('data:text/csv;charset=utf-8,' + escape(urls.join('\n')));**

# %% [markdown]
# ### Setup File Paths and Download Images into Respective Folders
# ---
# This whole area can be quite problematic. For that reason I am creating separate code blocks where I will setup each folder and file path and download the associated images for that labelled image set.
#
# Each step is run sequentially and will prevent mislabelling CSV files or downloading images labelled as one thing into an incorrect folder. This is not the most efficient way to code but it prevents errors that take hours to fix.

# %% [markdown]
# Below I am creating folders and image files for the 4 most popular wwood species for guitar tops. Spruce, Mahogany, Cedar and Koa.

# %% [markdown]
# #### Setup Folder, Files and Download Images #1
# ---

# %%
# Create the folder and file names

folder = 'specialized'
file = 'specialized.csv'

# %%
# Setup the directory and path

path = Path('data/racebike')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
# Download the images from path specified

download_images(path/file, dest, max_pics=200)

# %% [markdown]
# #### Setup Folder, Files and Download Images #2
#
# ---

# %%
# Create the folder and file names

folder = 'pinarello'
file = 'pinarello.csv'

# %%
# Setup the directory and path

path = Path('data/racebike')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
# Download the images from path specified

download_images(path/file, dest, max_pics=200)

# %% [markdown]
# #### Setup Folder, Files and Download Images
# ---

# %%
# Create the folder and file names

folder = 'orbea'
file = 'orbea.csv'

# %%
# Setup the directory and path

path = Path('data/racebike')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
# Download the images from path specified

download_images(path/file, dest, max_pics=200)

# %% [markdown]
# #### Setup Folder, Files and Download Images
#
# ---
#
#
# ---

# %%
# Create the folder and file names

folder = 'merida'
file = 'merida.csv'

# %%
# Setup the directory and path

path = Path('data/racebike')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
# Download the images from path specified

download_images(path/file, dest, max_pics=200)

# %% [markdown]
# #### Setup Folder, Files and Download Images
#
# ---

# %%
# Create the folder and file names

folder = 'lapierre'
file = 'lapierre.csv'

# %%
# Setup the directory and path

path = Path('data/racebike')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
# Download the images from path specified

download_images(path/file, dest, max_pics=200)

# %% [markdown]
# #### Setup Folder, Files and Download Images
#
# ---

# %%
# Create the folder and file names

folder = 'giant'
file = 'giant.csv'

# %%
# Setup the directory and path

path = Path('data/racebike')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
# Download the images from path specified

download_images(path/file, dest, max_pics=200)

# %% [markdown]
# #### Setup Folder, Files and Download Images
#
# ---

# %%
# Create the folder and file names

folder = 'focus'
file = 'focus.csv'

# %%
# Setup the directory and path

path = Path('data/racebike')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
# Download the images from path specified

download_images(path/file, dest, max_pics=200)

# %% [markdown]
# ### Setup Folder, Files and Download Images
#
# ---

# %%
# Create the folder and file names

folder = 'felt'
file = 'felt.csv'

# %%
# Setup the directory and path

path = Path('data/racebike')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
# Download the images from path specified

download_images(path/file, dest, max_pics=200)

# %% [markdown]
# ### Setup Folder, Files and Download Images
#
# ---

# %%
# Create the folder and file names

folder = 'cervelo'
file = 'cervelo.csv'

# %%
# Setup the directory and path

path = Path('data/racebike')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
# Download the images from path specified

download_images(path/file, dest, max_pics=200)

# %% [markdown]
# ### Setup Folder, Files and Download Images
#
# ---

# %%
# Create the folder and file names

folder = 'canyon'
file = 'canyon.csv'

# %%
# Setup the directory and path

path = Path('data/racebike')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
# Download the images from path specified

download_images(path/file, dest, max_pics=200)

# %% [markdown]
# ### Setup Folder, Files and Download Images
# ---

# %%
# Create the folder and file names

folder = 'bmc'
file = 'bmc.csv'

# %%
# Setup the directory and path

path = Path('data/racebike')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
# Download the images from path specified

download_images(path/file, dest, max_pics=200)

# %% [markdown]
# ### Setup Folder, Files and Download Images
# ---

# %%
# Create the folder and file names

folder = 'trek'
file = 'trek.csv'

# %%
# Setup the directory and path

path = Path('data/racebike')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
# Download the images from path specified

download_images(path/file, dest, max_pics=200)

# %% [markdown]
# ### Setup Folder, Files and Download Images
#
# ---

# %%
# Create the folder and file names

folder = 'bianchi'
file = 'bianchi.csv'

# %%
# Setup the directory and path

path = Path('data/racebike')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
# Download the images from path specified

download_images(path/file, dest, max_pics=200)

# %% [markdown]
# #### Check File Structure
#
# ---

# %%
# Check paths and file names
#print(path.ls())
path.ls()
# Out:
# [PosixPath('data/racebike/cervelo'),
#  PosixPath('data/racebike/lapierre'),
#  PosixPath('data/racebike/orbea'),
#  PosixPath('data/racebike/giant'),
#  PosixPath('data/racebike/felt'),
#  PosixPath('data/racebike/focus'),
#  PosixPath('data/racebike/giant.csv'),
#  PosixPath('data/racebike/trek'),
#  PosixPath('data/racebike/merida'),
#  PosixPath('data/racebike/orbea.csv'),
#  PosixPath('data/racebike/trek.csv'),
#  PosixPath('data/racebike/specialized'),
#  PosixPath('data/racebike/cervelo.csv'),
#  PosixPath('data/racebike/canyon'),
#  PosixPath('data/racebike/bianchi.csv'),
#  PosixPath('data/racebike/bmc'),
#  PosixPath('data/racebike/lapierre.csv'),
#  PosixPath('data/racebike/canyon.csv'),
#  PosixPath('data/racebike/bianchi'),
#  PosixPath('data/racebike/bmc.csv'),
#  PosixPath('data/racebike/felt.csv'),
#  PosixPath('data/racebike/pinarello.csv'),
#  PosixPath('data/racebike/merida.csv'),
#  PosixPath('data/racebike/focus.csv'),
#  PosixPath('data/racebike/pinarello'),
# ...

# %% [markdown]
# #### Create and Label Classes
# ---
#
# *   List This stage in the process does the following:
# Create a set of classes to identify the objects. These classes will be called using a fastai method called ".c"
# *   Then download the images using the "download_images" method in fastai and specying path and number of files.
# *   Following this we will examine the file using a simple for loop and a verify_images function
# *   Finally we will move to the section where we can view a sample of the data to check whether the untrained, source files have been categorised, labelled and filed in the right places. Amazing how many mistakes and incorrect labels are already apparent at this stage.

# %%
# Create Classes

classes = ['specialized', 'pinarello', 'orbea', 'merida', 'lapierre', 'giant', 'focus', 'felt', 'cervelo', 'canyon', 'bianchi', 'bmc', 'trek']
print(array(classes))
len(classes)
# Out:
# ['specialized' 'pinarello' 'orbea' 'merida' 'lapierre' 'giant' 'focus' 'felt' 'cervelo' 'canyon' 'bianchi' 'bmc' 'trek']
# 13

# %% [markdown]
# #### Verify Images and Delete Problematic Uploads
#
#
#
#
# ---

# %%
for c in classes:
    print(c)
    verify_images(path/c, delete=True, max_size=500)

    #This for loop verifies that all the images have uploaded correctly and deletes problematic images.
# Out:
# specialized
# pinarello
# orbea
# merida
# lapierre
# giant
# focus
# felt
# cervelo
# canyon
# bianchi
# bmc
# trek

# %% [markdown]
# #### Apply ImageDataBunch to Create Training and Validation Sets
#
#
# ---
#
#
#
# Then apply ImageDataBunch method to
# (1) create a training data path
# (2) split the data into training 80% and validation 20%,
# (3) transform the images into size 224 which appears to be a good default and
# (4)then run a normalise procedure.

# %%
# The ImageDataBunch is a critical function in the Pytorch/Fastai library - come back to it later. 

np.random.seed(42)
data = ImageDataBunch.from_folder(path, 
                                  train=".", 
                                  valid_pct=0.2, # Identify images, create a training and validation set with 80% - 20% split
                                  ds_tfms=get_transforms(), # Later on I will specify do_flip, flip_vert, max_rotate, max_warp etc
                                  size=224, # Here you determine the size of the images. Lower resolution possible if GPU capacity overload
                                  num_workers=4).normalize() # Normalize `x` with `mean` and `std` I am choosing not normalise here

# %% [markdown]
# #### Validate the class names and underlying split details
#
#
# ---

# %%
data.classes
# Out:
# ['bianchi',
#  'bmc',
#  'canyon',
#  'cervelo',
#  'felt',
#  'focus',
#  'giant',
#  'lapierre',
#  'merida',
#  'orbea',
#  'pinarello',
#  'specialized',
#  'trek']

# %%
data.c
#len(data.classes)

# %% [markdown]
# #### Review the images using the "data.show_batch" method in Fast.ai library
#
# ---

# %%
data.show_batch(rows=10, figsize=(20, 15))

# %%
## The images shown in the data batch are very accurate.

# %% [markdown]
# #### Check Classes and Dimensions of Training and Validation
#
# ---
#
# Check classes, number, length of training and length of validation

# %%
# Check classes, dimensions and size of Training and Validation

data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['bianchi',
#   'bmc',
#   'canyon',
#   'cervelo',
#   'felt',
#   'focus',
#   'giant',
#   'lapierre',
#   'merida',
#   'orbea',
#   'pinarello',
#   'specialized',
#   'trek'],
#  13,
#  896,
#  224)

# %% [markdown]
# # **Phase 2: Training The Model using Resnet34**
#
# ---
#
#
#
# ---

# %% [markdown]
# ## Train the Model
#
#
# ---
#
#
#
# Step 1: Build the CNN learner using Resnet and setting the error rate as the key metric. This can be changed to Resnet50 or another network architecutre later on
#
# Step 2: Run the model using "Fit One Cycle" and doing it against 4 epochs. Again this can be altered later on with more or fewer epochs.
#
# Step 3: Save the model as a checkpoint as "topwood_stage1". This makes it more efficient later when reloading.
#
# Step 4: Unfreeze the weights and bias in the model. This will be unpacked as the models become more sophisticated - for now I am doing it all off the shelf
#
# Step 5: Now I run the lr_find() function to try to deterine the optimal learning rate so that the stochasitc gradient decent are not too high (overshoot) and not too low (get stuck with a local minimum)
#
# Step 6: We will fit the model a few more times and mess around with the learning rate and epoch sizes to see if we can improve error rates. Generally I think there will be some refinement of images needed because the error rates are high. See below.

# %% [markdown]
# **Create Learner **

# %%
# Build the learner using a Convolutional Neural Network

learn = cnn_learner(data, models.resnet34, metrics=error_rate) # Later if I can get this thing sorted I will go back and do a ResNet50 model

# %% [markdown]
# **Fit Model**

# %%
# Here I am running the first learner. 
# It will use "Fit One Cycle" which is current best practice.
learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.919317</td>
#       <td>2.811248</td>
#       <td>0.816964</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.310520</td>
#       <td>2.660700</td>
#       <td>0.727679</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.823507</td>
#       <td>2.548697</td>
#       <td>0.718750</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.554287</td>
#       <td>2.481963</td>
#       <td>0.727679</td>
#       <td>00:09</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Save Model**

# %%
# I am saving this first learn iteration as topwood_stage1. 
# It can be reloaded from here without having to go through preliminary steps

learn.save('stage1-4ep')

# %% [markdown]
# **Scan Results**

# %%
interp = ClassificationInterpretation.from_learner(learn)

losses,idxs = interp.top_losses()

len(data.valid_ds)==len(losses)==len(idxs)

# %% [markdown]
# Plot Top Losses
#
# There is a fair amount of confusion in the model when it comes to the default settings. We will really need to get stuck into the training - more epochs and better learning rates

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %% [markdown]
# Confusion Matrix
# Clearly there are a lot of incorrect classifications. Further training required. Maybe in later scenario we need to take a look at resnet50

# %%
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

# %% [markdown]
# **Model is most confused about the following bike brands**

# %%
interp.most_confused(min_val=2)
# Out:
# [('canyon', 'bmc', 5),
#  ('cervelo', 'specialized', 5),
#  ('giant', 'bmc', 5),
#  ('bmc', 'specialized', 4),
#  ('felt', 'bmc', 4),
#  ('focus', 'bmc', 4),
#  ('trek', 'bmc', 4),
#  ('trek', 'merida', 4),
#  ('bmc', 'cervelo', 3),
#  ('canyon', 'pinarello', 3),
#  ('cervelo', 'bmc', 3),
#  ('focus', 'specialized', 3),
#  ('giant', 'specialized', 3),
#  ('orbea', 'cervelo', 3),
#  ('orbea', 'specialized', 3),
#  ('pinarello', 'lapierre', 3),
#  ('pinarello', 'orbea', 3),
#  ('specialized', 'bmc', 3),
#  ('bianchi', 'specialized', 2),
#  ('bmc', 'lapierre', 2),
#  ('bmc', 'trek', 2),
#  ('canyon', 'cervelo', 2),
#  ('canyon', 'felt', 2),
#  ('canyon', 'merida', 2),
#  ('canyon', 'specialized', 2),
#  ('cervelo', 'giant', 2),
#  ('felt', 'bianchi', 2),
#  ('felt', 'specialized', 2),
#  ('focus', 'cervelo', 2),
#  ('giant', 'felt', 2),
#  ('lapierre', 'bianchi', 2),
#  ('lapierre', 'felt', 2),
#  ('lapierre', 'merida', 2),
#  ('lapierre', 'specialized', 2),
# ...

# %% [markdown]
# #### Unfreeze, Fine Tune and Identify Learning Rates
#
# ---

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.975578</td>
#       <td>2.749263</td>
#       <td>0.718750</td>
#       <td>00:10</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.load('stage1-4ep');

# %% [markdown]
# **Find Learning Rate**

# %%
learn.lr_find() # Here I am trying to find the point at which the learning rate starts to curve upwards. Then step back to high point of slope for ooptimal learning rate
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='6' class='' max='8', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       75.00% [6/8 00:53<00:17]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
# ...

# %% [markdown]
# **Visualise Learning Rate**

# %%
# If the plot is not showing try to give a start and end learning rate
# learn.lr_find(start_lr=1e-5, end_lr=1e-1)

learn.recorder.plot()

# I will check out LR 1e-5 - 1e-4

# %% [markdown]
# **Run New Cycle**

# %%
# 5 Epoch LR 6-4

learn.fit_one_cycle(5, max_lr=slice(1e-6, 1e-4))

# Using the new learning rates the errors are still very very high. 
# This setting does not help the error rates. I will change learning rate and epochs in further cycles
# LR could be causing a problem with local minimum - there is a dip after the 1e-6
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.956175</td>
#       <td>2.459958</td>
#       <td>0.718750</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.918864</td>
#       <td>2.410805</td>
#       <td>0.723214</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.880321</td>
#       <td>2.380328</td>
#       <td>0.727679</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.870504</td>
#       <td>2.372609</td>
#       <td>0.727679</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.848031</td>
#       <td>2.362821</td>
#       <td>0.709821</td>
#       <td>00:10</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Save Cycle**

# %%
# Here I will run a new fit one cycle, with default learning rates. So no reference to the chart above. 
learn.save('stage2-5epoch_lr64')

# %% [markdown]
# **Run New Cycle**

# %%
# 6 Epoch - LR 5-4

learn.fit_one_cycle(6, max_lr=slice(1e-5, 1e-4))

## Some improvemen in learning rates. I will iterate below
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.688261</td>
#       <td>2.348574</td>
#       <td>0.705357</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.697706</td>
#       <td>2.309256</td>
#       <td>0.696429</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.629677</td>
#       <td>2.285796</td>
#       <td>0.665179</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.516311</td>
#       <td>2.271941</td>
#       <td>0.674107</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.443559</td>
#       <td>2.265575</td>
#       <td>0.669643</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %% [markdown]
# **Save Cycle**

# %%
learn.save('stage3-6epoch-lr54')

# %% [markdown]
# **Run New Cycle**

# %%
# 8 epoch and LR 5-3

learn.fit_one_cycle(8, max_lr=slice(1e-5, 1e-3))

# Once again a significant improvement in the error rates and training losses. 
# I will continue to train the model until the training loss starts to move upward
# I suspect the Learning Rate is a big driver for improvement - better slope
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.270814</td>
#       <td>2.261889</td>
#       <td>0.678571</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.194515</td>
#       <td>2.167222</td>
#       <td>0.589286</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.080343</td>
#       <td>2.258764</td>
#       <td>0.593750</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.977109</td>
#       <td>2.192463</td>
#       <td>0.580357</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.880238</td>
#       <td>2.023162</td>
#       <td>0.535714</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %% [markdown]
# **Save Cycle**

# %%
learn.save('stage4-8epoch-lr5-3')

# %% [markdown]
# **Run New Cycle**

# %%
# 10 Epoch LR 5-3

learn.fit_one_cycle(10, max_lr=slice(1e-5, 1e-3))

#Here we see that the training losses are still dropping and error rates are not at 40. But are we overtraining?
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.368133</td>
#       <td>1.985793</td>
#       <td>0.558036</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.376462</td>
#       <td>2.024723</td>
#       <td>0.535714</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.352960</td>
#       <td>2.066542</td>
#       <td>0.513393</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.343307</td>
#       <td>2.171331</td>
#       <td>0.526786</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.328319</td>
#       <td>2.262805</td>
#       <td>0.522321</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %% [markdown]
# **Save Cycle**

# %%
learn.save('stage5-10epoch-lr53')

# %% [markdown]
# Run New Cycle

# %%
# 12 Epoch LR 5-3

learn.fit_one_cycle(12, max_lr=slice(1e-5, 1e-3))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.145939</td>
#       <td>2.061075</td>
#       <td>0.517857</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.138174</td>
#       <td>2.149425</td>
#       <td>0.531250</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.138051</td>
#       <td>2.088310</td>
#       <td>0.482143</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.147780</td>
#       <td>2.177351</td>
#       <td>0.513393</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.153835</td>
#       <td>2.698204</td>
#       <td>0.549107</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %% [markdown]
# **Save Cycle**

# %%
learn.save('stage6-12epoch-lr53')

# %% [markdown]
# **Run New Cycle**

# %%
# 15 Epoch LR 6-3 (broaden the learning rate - to check)

learn.fit_one_cycle(15, max_lr=slice(1e-6, 1e-3))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.069560</td>
#       <td>2.231034</td>
#       <td>0.450893</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.073388</td>
#       <td>2.239128</td>
#       <td>0.459821</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.064478</td>
#       <td>2.232781</td>
#       <td>0.468750</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.062812</td>
#       <td>2.337686</td>
#       <td>0.495536</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.059208</td>
#       <td>2.226126</td>
#       <td>0.468750</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %% [markdown]
# **Save Cycle**

# %%
learn.save('stage7-15epoch-lr63')

# %%
learn.unfreeze()

# %% [markdown]
# #### Unfreeze Model and Redo LR Find
#
# ---

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3' class='' max='8', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       37.50% [3/8 00:27<00:46]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
# ...

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(15, max_lr=slice(1e-6,1e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.035845</td>
#       <td>2.399843</td>
#       <td>0.455357</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.038054</td>
#       <td>2.424988</td>
#       <td>0.455357</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.030020</td>
#       <td>2.369827</td>
#       <td>0.441964</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.028890</td>
#       <td>2.367932</td>
#       <td>0.441964</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.026117</td>
#       <td>2.377338</td>
#       <td>0.450893</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
learn.save('stage8-15epoch-lr64')

# %% [markdown]
# #### Interpreting the Results
#
# ---
#
#
# Here we will reload one of the saved models to bypass the first stages in the process and using Classification Interpreter and a Confusion Matrix to see where we can find the most errors.

# %%
learn.load('stage7-15epoch-lr63')
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (896 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# cervelo,cervelo,cervelo,cervelo,cervelo
# Path: data/racebike;
#
# Valid: LabelList (224 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# giant,lapierre,bianchi,pinarello,trek
# Path: data/racebike;
#
# Test: None, model=Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.most_confused()
# Out:
# [('canyon', 'specialized', 4),
#  ('felt', 'cervelo', 4),
#  ('trek', 'specialized', 4),
#  ('giant', 'orbea', 3),
#  ('giant', 'specialized', 3),
#  ('pinarello', 'orbea', 3),
#  ('bianchi', 'merida', 2),
#  ('bmc', 'canyon', 2),
#  ('bmc', 'giant', 2),
#  ('bmc', 'merida', 2),
#  ('canyon', 'felt', 2),
#  ('canyon', 'pinarello', 2),
#  ('cervelo', 'pinarello', 2),
#  ('felt', 'orbea', 2),
#  ('giant', 'felt', 2),
#  ('giant', 'pinarello', 2),
#  ('lapierre', 'bmc', 2),
#  ('merida', 'giant', 2),
#  ('orbea', 'merida', 2),
#  ('orbea', 'specialized', 2),
#  ('trek', 'lapierre', 2),
#  ('bmc', 'bianchi', 1),
#  ('bmc', 'specialized', 1),
#  ('bmc', 'trek', 1),
#  ('canyon', 'bianchi', 1),
#  ('canyon', 'bmc', 1),
#  ('canyon', 'merida', 1),
#  ('canyon', 'trek', 1),
#  ('cervelo', 'bianchi', 1),
#  ('cervelo', 'focus', 1),
#  ('cervelo', 'orbea', 1),
#  ('felt', 'bmc', 1),
#  ('felt', 'focus', 1),
#  ('felt', 'giant', 1),
#  ('felt', 'lapierre', 1),
#  ('felt', 'merida', 1),
# ...

# %%
# Now let's visualise this as a Confusion Matrix

interp.plot_confusion_matrix()

## So here we can see a huge immprovement in the error rates .
# There are still substantial errors, but the classification task is quite challenging

# %% [markdown]
# #### Validating the Model Works
#
# ---
# There is a massive improvement in the classification matrix. It might be worth throwing a few images at the model to see how well they come out.

# %% [markdown]
# Export the Trained Model
#
# This will create a file named 'export.pkl' in the directory where we were working that contains everything we need to deploy our model (the model, the weights but also some metadata like the classes or the transforms/normalization used).

# %%
learn.export()

# %% [markdown]
# **Switch to CPU Device**
#
# ---
#
# Prediction/Inference doesnt need a GPU!

# %% [markdown]
# You probably want to use CPU for inference, except at massive scale (and you almost certainly don't need to train in real-time). If you don't have a GPU that happens automatically. You can test your model on CPU like so:

# %%
defaults.device = torch.device('cpu')

# %%
img1 = open_image(path/'bmc'/'00000010.jpg') # BMC Roadmachine
img1
# Out:
# Image (3, 194, 260)

# %%
learn = load_learner(path)

# %%
pred_class,pred_idx,outputs = learn.predict(img1)
pred_class
# Out:
# Category bmc

# %%
img2 = open_image(path/'canyon'/'00000031.jpg') # Canyon
img2
# Out:
# Image (3, 191, 264)

# %%
pred_class,pred_idx,outputs = learn.predict(img2)
pred_class
# Out:
# Category canyon

# %%
img3 = open_image(path/'felt'/'00000071.jpg') # Felt
img3
# Out:
# Image (3, 225, 225)

# %%
pred_class,pred_idx,outputs = learn.predict(img3)
pred_class
# Out:
# Category felt

# %%
# I will give Giant a shot - it seems to have a few conlicts in the Confusion Matrix

img4 = open_image(path/'giant'/'00000012.jpg') # Giant
img4
# Out:
# Image (3, 225, 225)

# %%
pred_class,pred_idx,outputs = learn.predict(img4)
pred_class
# Out:
# Category pinarello

# %%
# I will give Giant a shot - it seems to have a few conlicts in the Confusion Matrix

img5 = open_image(path/'giant'/'00000006.jpg') # Giant
img5
# Out:
# Image (3, 181, 278)

# %%
pred_class,pred_idx,outputs = learn.predict(img5)
pred_class
# Out:
# Category pinarello

# %%
# Specialized

img6 = open_image(path/'specialized'/'00000001.jpg') # Specialized
img6
# Out:
# Image (3, 168, 300)

# %%
pred_class,pred_idx,outputs = learn.predict(img6)
pred_class
# Out:
# Category pinarello

# %% [markdown]
# ## Phase 2: Build Classification on Resnet50
#
# ---
#
# Resnet50 usually performs better because it is a deeper network with more parameters. Let's see if we can achieve a higher performance here. To help it along, let's us use larger images too, since that way the network can see more detail. We reduce the batch size a bit since otherwise this larger network will require more GPU memory.

# %%
# Run the learner on a Resnet50

learn2 = cnn_learner(data, models.resnet50, metrics=error_rate) #

# %%
learn2.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.669447</td>
#       <td>2.875914</td>
#       <td>0.741071</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.035689</td>
#       <td>2.710309</td>
#       <td>0.674107</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.522005</td>
#       <td>2.273395</td>
#       <td>0.651786</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.175339</td>
#       <td>2.178761</td>
#       <td>0.638393</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn2.save('stage1-res50')

# %%
learn2.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='6' class='' max='8', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       75.00% [6/8 01:00<00:20]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
# ...

# %%
learn2.recorder.plot()

# %%
learn2.fit_one_cycle(6, max_lr=slice(1e-5, 1e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.564342</td>
#       <td>2.154413</td>
#       <td>0.633929</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.574297</td>
#       <td>2.140455</td>
#       <td>0.633929</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.546867</td>
#       <td>2.108756</td>
#       <td>0.620536</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.531825</td>
#       <td>2.120053</td>
#       <td>0.620536</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.503134</td>
#       <td>2.102486</td>
#       <td>0.611607</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
learn2.save('stage2-res50')

# %%
learn2.fit_one_cycle(10, max_lr=slice(1e-6, 1e-3))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.415158</td>
#       <td>2.078604</td>
#       <td>0.611607</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.348298</td>
#       <td>2.037979</td>
#       <td>0.620536</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.316520</td>
#       <td>2.051647</td>
#       <td>0.607143</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.282110</td>
#       <td>2.008583</td>
#       <td>0.589286</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.207456</td>
#       <td>1.945573</td>
#       <td>0.571429</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
learn2.save('stage3-res50')

# %%
learn2.fit_one_cycle(15, max_lr=slice(1e-6, 1e-3))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.833381</td>
#       <td>1.872318</td>
#       <td>0.535714</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.828762</td>
#       <td>1.868696</td>
#       <td>0.553571</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.794385</td>
#       <td>1.880760</td>
#       <td>0.549107</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.782400</td>
#       <td>1.908533</td>
#       <td>0.571429</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.770468</td>
#       <td>1.938807</td>
#       <td>0.575893</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
learn2.save('stage4-res50')

# %% [markdown]
# My conclusion from above is that Resnet 50 does not necessarily offer any benefits so I will stick with Resnet34. Maybe if I tried more runs it would change.

# %%
#learn2.load('stage4-res50')

# %%
#interp = ClassificationInterpretation.from_learner(learn2)

# %%
#interp.most_confused()

# %%
interp.plot_confusion_matrix()

# %%
learn2.export()

# %% [markdown]
# ## Phase 3: Create a simple Web Service and Publish
#
# ---
#
#
#
# ---
